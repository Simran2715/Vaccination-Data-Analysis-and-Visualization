# %%
import pandas as pd
import openpyxl
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
File_1=r"C:\Users\simra\OneDrive\Documents\Coding_files\Vaccination_Data_Analysis\coverage-data.xlsx"
df_coverage=pd.read_excel(File_1, sheet_name='Data')
df_coverage
# Out:
#                                 GROUP CODE                    NAME    YEAR  \
# 0                           COUNTRIES  ABW                   Aruba  2023.0
# 1                           COUNTRIES  ABW                   Aruba  2023.0
# 2                           COUNTRIES  ABW                   Aruba  2023.0
# 3                           COUNTRIES  ABW                   Aruba  2023.0
# 4                           COUNTRIES  ABW                   Aruba  2023.0
# ...                               ...  ...                     ...     ...
# 399854                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399855                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399856                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399857                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399858  Created: 2025-02-01 16:00 UTC  NaN                     NaN     NaN
#
# ...

# %%
File_2=r"C:\Users\simra\OneDrive\Documents\Coding_files\Vaccination_Data_Analysis\incidence-rate-data.xlsx"
df_incidence=pd.read_excel(File_2, sheet_name='Data')
df_incidence
# Out:
#                                GROUP CODE      NAME    YEAR          DISEASE  \
# 0                          COUNTRIES  ABW     Aruba  2023.0              CRS
# 1                          COUNTRIES  ABW     Aruba  2023.0       DIPHTHERIA
# 2                          COUNTRIES  ABW     Aruba  2023.0  INVASIVE_MENING
# 3                          COUNTRIES  ABW     Aruba  2023.0          MEASLES
# 4                          COUNTRIES  ABW     Aruba  2023.0            MUMPS
# ...                              ...  ...       ...     ...              ...
# 84941                      COUNTRIES  ZWE  Zimbabwe  1980.0        PERTUSSIS
# 84942                      COUNTRIES  ZWE  Zimbabwe  1980.0            POLIO
# 84943                      COUNTRIES  ZWE  Zimbabwe  1980.0         TTETANUS
# 84944                      COUNTRIES  ZWE  Zimbabwe  1980.0           YFEVER
# 84945  Created: 2025-02-01 16:03 UTC  NaN       NaN     NaN              NaN
#
# ...

# %%
File_3=r"C:\Users\simra\OneDrive\Documents\Coding_files\Vaccination_Data_Analysis\reported-cases-data.xlsx"
df_reported_cases=pd.read_excel(File_3, sheet_name='Data')
df_reported_cases
# Out:
#                                GROUP CODE      NAME    YEAR          DISEASE  \
# 0                          COUNTRIES  ABW     Aruba  2023.0              CRS
# 1                          COUNTRIES  ABW     Aruba  2023.0       DIPHTHERIA
# 2                          COUNTRIES  ABW     Aruba  2023.0  INVASIVE_MENING
# 3                          COUNTRIES  ABW     Aruba  2023.0          MEASLES
# 4                          COUNTRIES  ABW     Aruba  2023.0            MUMPS
# ...                              ...  ...       ...     ...              ...
# 84865                      COUNTRIES  ZWE  Zimbabwe  1980.0        PERTUSSIS
# 84866                      COUNTRIES  ZWE  Zimbabwe  1980.0            POLIO
# 84867                      COUNTRIES  ZWE  Zimbabwe  1980.0         TTETANUS
# 84868                      COUNTRIES  ZWE  Zimbabwe  1980.0           YFEVER
# 84869  Created: 2025-02-01 16:02 UTC  NaN       NaN     NaN              NaN
#
# ...

# %%
File_4=r"C:\Users\simra\OneDrive\Documents\Coding_files\Vaccination_Data_Analysis\vaccine-introduction-data.xlsx"
df_vaccine_introduction=pd.read_excel(File_4, sheet_name='Data')
df_vaccine_introduction
# Out:
#                            ISO_3_CODE  COUNTRYNAME WHO_REGION    YEAR  \
# 0                                 AFG  Afghanistan       EMRO  2023.0
# 1                                 AFG  Afghanistan       EMRO  2023.0
# 2                                 AFG  Afghanistan       EMRO  2023.0
# 3                                 AFG  Afghanistan       EMRO  2023.0
# 4                                 AFG  Afghanistan       EMRO  2023.0
# ...                               ...          ...        ...     ...
# 138316                            ZWE     Zimbabwe       AFRO  1943.0
# 138317                            ZWE     Zimbabwe       AFRO  1942.0
# 138318                            ZWE     Zimbabwe       AFRO  1941.0
# 138319                            ZWE     Zimbabwe       AFRO  1940.0
# 138320  Created: 2025-02-01 07:09 UTC          NaN        NaN     NaN
#
#                                         DESCRIPTION INTRO
# 0                  aP (acellular pertussis) vaccine    No
# ...

# %%
File_5=r"C:\Users\simra\OneDrive\Documents\Coding_files\Vaccination_Data_Analysis\vaccine-schedule-data.xlsx"
df_vaccine_schedule=pd.read_excel(File_5, sheet_name='Data')
df_vaccine_schedule
# Out:
#                          ISO_3_CODE COUNTRYNAME WHO_REGION    YEAR  \
# 0                               ABW       Aruba       AMRO  2023.0
# 1                               ABW       Aruba       AMRO  2023.0
# 2                               ABW       Aruba       AMRO  2023.0
# 3                               ABW       Aruba       AMRO  2023.0
# 4                               ABW       Aruba       AMRO  2023.0
# ...                             ...         ...        ...     ...
# 8048                            ZWE    Zimbabwe       AFRO  2023.0
# 8049                            ZWE    Zimbabwe       AFRO  2023.0
# 8050                            ZWE    Zimbabwe       AFRO  2023.0
# 8051                            ZWE    Zimbabwe       AFRO  2023.0
# 8052  Created: 2025-02-01 16:10 UTC         NaN        NaN     NaN
#
#      VACCINECODE               VACCINE_DESCRIPTION  SCHEDULEROUNDS  TARGETPOP  \
# 0     DTAPHIBIPV  DTaP-Hib-IPV (acellular) vaccine             1.0        NaN
# ...

# %%
print(df_coverage.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399859 entries, 0 to 399858
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   GROUP                          399859 non-null  object
#  1   CODE                           399858 non-null  object
#  2   NAME                           398584 non-null  object
#  3   YEAR                           399858 non-null  float64
#  4   ANTIGEN                        399858 non-null  object
#  5   ANTIGEN_DESCRIPTION            399858 non-null  object
#  6   COVERAGE_CATEGORY              399858 non-null  object
#  7   COVERAGE_CATEGORY_DESCRIPTION  399858 non-null  object
#  8   TARGET_NUMBER                  79030 non-null   float64
#  9   DOSES                          79327 non-null   float64
#  10  COVERAGE                       230477 non-null  float64
# dtypes: float64(4), object(7)
# memory usage: 33.6+ MB
# None

# %%
print(df_coverage.describe())
# Out:
#                 YEAR  TARGET_NUMBER         DOSES       COVERAGE
# count  399858.000000   7.903000e+04  7.932700e+04  230477.000000
# mean     2009.207489   2.780192e+08  3.467241e+06      78.032914
# std        11.720530   5.415244e+10  1.125676e+07      74.891697
# min      1980.000000   0.000000e+00 -2.222882e+08       0.000000
# 25%      2002.000000   3.281400e+04  1.446900e+04      69.320000
# 50%      2012.000000   3.178715e+05  1.522120e+05      88.790000
# 75%      2019.000000   2.493048e+06  9.710185e+05      96.000000
# max      2023.000000   1.170000e+13  1.266052e+08   32000.000000

# %%
df_coverage.drop_duplicates(inplace=True)

# %%
df_coverage.head()
# Out:
#        GROUP CODE   NAME    YEAR  ANTIGEN  \
# 0  COUNTRIES  ABW  Aruba  2023.0      BCG
# 1  COUNTRIES  ABW  Aruba  2023.0      BCG
# 2  COUNTRIES  ABW  Aruba  2023.0  DIPHCV4
# 3  COUNTRIES  ABW  Aruba  2023.0  DIPHCV4
# 4  COUNTRIES  ABW  Aruba  2023.0  DIPHCV5
#
#                                  ANTIGEN_DESCRIPTION COVERAGE_CATEGORY  \
# 0                                                BCG             ADMIN
# 1                                                BCG          OFFICIAL
# 2  Diphtheria-containing vaccine, 4th dose (1st b...             ADMIN
# 3  Diphtheria-containing vaccine, 4th dose (1st b...          OFFICIAL
# 4  Diphtheria-containing vaccine, 5th dose (2nd b...             ADMIN
#
#   COVERAGE_CATEGORY_DESCRIPTION  TARGET_NUMBER   DOSES  COVERAGE
# 0       Administrative coverage            NaN     NaN       NaN
# 1             Official coverage            NaN     NaN       NaN
# 2       Administrative coverage         1044.0   945.0     90.52
# ...

# %%
df_coverage.isnull().sum()
# Out:
# GROUP                                 0
# CODE                                  1
# NAME                               1275
# YEAR                                  1
# ANTIGEN                               1
# ANTIGEN_DESCRIPTION                   1
# COVERAGE_CATEGORY                     1
# COVERAGE_CATEGORY_DESCRIPTION         1
# TARGET_NUMBER                    320829
# DOSES                            320532
# COVERAGE                         169382
# dtype: int64

# %%
mean_doses=df_coverage['DOSES'].mean()
df_coverage.loc[:,'DOSES']=df_coverage['DOSES'].fillna(mean_doses)
coverage_mean=df_coverage['COVERAGE'].mean()
df_coverage.loc[:,'COVERAGE']=df_coverage['COVERAGE'].fillna(coverage_mean)

# %%
df_coverage.head()
# Out:
#        GROUP CODE   NAME    YEAR  ANTIGEN  \
# 0  COUNTRIES  ABW  Aruba  2023.0      BCG
# 1  COUNTRIES  ABW  Aruba  2023.0      BCG
# 2  COUNTRIES  ABW  Aruba  2023.0  DIPHCV4
# 3  COUNTRIES  ABW  Aruba  2023.0  DIPHCV4
# 4  COUNTRIES  ABW  Aruba  2023.0  DIPHCV5
#
#                                  ANTIGEN_DESCRIPTION COVERAGE_CATEGORY  \
# 0                                                BCG             ADMIN
# 1                                                BCG          OFFICIAL
# 2  Diphtheria-containing vaccine, 4th dose (1st b...             ADMIN
# 3  Diphtheria-containing vaccine, 4th dose (1st b...          OFFICIAL
# 4  Diphtheria-containing vaccine, 5th dose (2nd b...             ADMIN
#
#   COVERAGE_CATEGORY_DESCRIPTION  TARGET_NUMBER         DOSES   COVERAGE
# 0       Administrative coverage            NaN  3.467241e+06  78.032914
# 1             Official coverage            NaN  3.467241e+06  78.032914
# ...

# %%
df_coverage.dropna(inplace=True)

# %%
df_coverage['YEAR']=df_coverage['YEAR'].astype('int')
df_coverage['TARGET_NUMBER']=df_coverage['TARGET_NUMBER'].astype('int')
df_coverage['DOSES']=df_coverage['DOSES'].astype('int')

# %%
df_coverage.isnull().sum()
# Out:
# GROUP                            0
# CODE                             0
# NAME                             0
# YEAR                             0
# ANTIGEN                          0
# ANTIGEN_DESCRIPTION              0
# COVERAGE_CATEGORY                0
# COVERAGE_CATEGORY_DESCRIPTION    0
# TARGET_NUMBER                    0
# DOSES                            0
# COVERAGE                         0
# dtype: int64

# %%
df_coverage.rename(columns=lambda x: x.strip().lower(), inplace=True)
df_coverage=df_coverage.rename(columns={'group' : 'group_name'})

# %%
df_coverage.head()
# Out:
#    group_name code   name  year  antigen  \
# 2   COUNTRIES  ABW  Aruba  2023  DIPHCV4
# 4   COUNTRIES  ABW  Aruba  2023  DIPHCV5
# 6   COUNTRIES  ABW  Aruba  2023  DIPHCV6
# 8   COUNTRIES  ABW  Aruba  2023   DTPCV1
# 10  COUNTRIES  ABW  Aruba  2023   DTPCV3
#
#                                   antigen_description coverage_category  \
# 2   Diphtheria-containing vaccine, 4th dose (1st b...             ADMIN
# 4   Diphtheria-containing vaccine, 5th dose (2nd b...             ADMIN
# 6   Diphtheria-containing vaccine, 6th dose (3rd b...             ADMIN
# 8                    DTP-containing vaccine, 1st dose             ADMIN
# 10                   DTP-containing vaccine, 3rd dose             ADMIN
#
#    coverage_category_description  target_number  doses  coverage
# 2        Administrative coverage           1044    945     90.52
# 4        Administrative coverage           1219   1008     82.69
# 6        Administrative coverage           1468   1219     83.04
# ...

# %%
df_coverage.to_csv('cleaned_coverage_data.csv', index=False)

# %%
#---------------------------------------------------------INCIDENCE DATA CLEANING--------------------------------------------------------------------------------------------------------------------------

# %%
df_incidence.isnull().sum()
# Out:
# GROUP                      0
# CODE                       1
# NAME                       1
# YEAR                       1
# DISEASE                    1
# DISEASE_DESCRIPTION        1
# DENOMINATOR                1
# INCIDENCE_RATE         23362
# dtype: int64

# %%
df_incidence.tail()
# Out:
#                                GROUP CODE      NAME    YEAR    DISEASE  \
# 84941                      COUNTRIES  ZWE  Zimbabwe  1980.0  PERTUSSIS
# 84942                      COUNTRIES  ZWE  Zimbabwe  1980.0      POLIO
# 84943                      COUNTRIES  ZWE  Zimbabwe  1980.0   TTETANUS
# 84944                      COUNTRIES  ZWE  Zimbabwe  1980.0     YFEVER
# 84945  Created: 2025-02-01 16:03 UTC  NaN       NaN     NaN        NaN
#
#       DISEASE_DESCRIPTION                     DENOMINATOR  INCIDENCE_RATE
# 84941           Pertussis  per 1,000,000 total population           893.3
# 84942       Poliomyelitis    per 1,000,000 <15 population             NaN
# 84943       Total tetanus  per 1,000,000 total population            19.7
# 84944        Yellow fever  per 1,000,000 total population             NaN
# 84945                 NaN                             NaN             NaN

# %%
df_incidence.describe()
# Out:
#                YEAR  INCIDENCE_RATE
# count  84945.000000    61584.000000
# mean    2004.095791      109.448781
# std       12.595166      992.276983
# min     1980.000000        0.000000
# 25%     1994.000000        0.000000
# 50%     2005.000000        0.000000
# 75%     2015.000000        4.600000
# max     2023.000000    69101.300000

# %%
df_incidence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84946 entries, 0 to 84945
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GROUP                84946 non-null  object
#  1   CODE                 84945 non-null  object
#  2   NAME                 84945 non-null  object
#  3   YEAR                 84945 non-null  float64
#  4   DISEASE              84945 non-null  object
#  5   DISEASE_DESCRIPTION  84945 non-null  object
#  6   DENOMINATOR          84945 non-null  object
#  7   INCIDENCE_RATE       61584 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 5.2+ MB

# %%
df_incidence.drop_duplicates(inplace=True)

# %%
df_incidence.head()
# Out:
#        GROUP CODE   NAME    YEAR          DISEASE  \
# 0  COUNTRIES  ABW  Aruba  2023.0              CRS
# 1  COUNTRIES  ABW  Aruba  2023.0       DIPHTHERIA
# 2  COUNTRIES  ABW  Aruba  2023.0  INVASIVE_MENING
# 3  COUNTRIES  ABW  Aruba  2023.0          MEASLES
# 4  COUNTRIES  ABW  Aruba  2023.0            MUMPS
#
#               DISEASE_DESCRIPTION                     DENOMINATOR  \
# 0     Congenital rubella syndrome          per 10,000 live births
# 1                      Diphtheria  per 1,000,000 total population
# 2  Invasive meningococcal disease  per 1,000,000 total population
# 3                         Measles  per 1,000,000 total population
# 4                           Mumps  per 1,000,000 total population
#
#    INCIDENCE_RATE
# 0             0.0
# 1             0.0
# 2             9.3
# 3             NaN
# 4             0.0

# %%
incidence_mean=df_incidence['INCIDENCE_RATE'].mean()
df_incidence.loc[:,'INCIDENCE_RATE']=df_incidence['INCIDENCE_RATE'].fillna(incidence_mean)

# %%
df_incidence.tail()
# Out:
#                                GROUP CODE      NAME    YEAR    DISEASE  \
# 84941                      COUNTRIES  ZWE  Zimbabwe  1980.0  PERTUSSIS
# 84942                      COUNTRIES  ZWE  Zimbabwe  1980.0      POLIO
# 84943                      COUNTRIES  ZWE  Zimbabwe  1980.0   TTETANUS
# 84944                      COUNTRIES  ZWE  Zimbabwe  1980.0     YFEVER
# 84945  Created: 2025-02-01 16:03 UTC  NaN       NaN     NaN        NaN
#
#       DISEASE_DESCRIPTION                     DENOMINATOR  INCIDENCE_RATE
# 84941           Pertussis  per 1,000,000 total population      893.300000
# 84942       Poliomyelitis    per 1,000,000 <15 population      109.448781
# 84943       Total tetanus  per 1,000,000 total population       19.700000
# 84944        Yellow fever  per 1,000,000 total population      109.448781
# 84945                 NaN                             NaN      109.448781

# %%
df_incidence.isnull().sum()
# Out:
# GROUP                  0
# CODE                   1
# NAME                   1
# YEAR                   1
# DISEASE                1
# DISEASE_DESCRIPTION    1
# DENOMINATOR            1
# INCIDENCE_RATE         0
# dtype: int64

# %%
df_incidence.dropna(inplace=True)

# %%
df_incidence.isnull().sum()
# Out:
# GROUP                  0
# CODE                   0
# NAME                   0
# YEAR                   0
# DISEASE                0
# DISEASE_DESCRIPTION    0
# DENOMINATOR            0
# INCIDENCE_RATE         0
# dtype: int64

# %%
df_incidence['YEAR']=df_incidence['YEAR'].astype('int')

# %%
df_incidence.rename(columns=lambda x: x.strip().lower(), inplace=True)
df_incidence=df_incidence.rename(columns={'group' : 'group_name'})

# %%
df_incidence.tail()
# Out:
#       group_name code      name  year    disease disease_description  \
# 84940  COUNTRIES  ZWE  Zimbabwe  1980   NTETANUS    Neonatal tetanus
# 84941  COUNTRIES  ZWE  Zimbabwe  1980  PERTUSSIS           Pertussis
# 84942  COUNTRIES  ZWE  Zimbabwe  1980      POLIO       Poliomyelitis
# 84943  COUNTRIES  ZWE  Zimbabwe  1980   TTETANUS       Total tetanus
# 84944  COUNTRIES  ZWE  Zimbabwe  1980     YFEVER        Yellow fever
#
#                           denominator  incidence_rate
# 84940           per 1,000 live births        0.400000
# 84941  per 1,000,000 total population      893.300000
# 84942    per 1,000,000 <15 population      109.448781
# 84943  per 1,000,000 total population       19.700000
# 84944  per 1,000,000 total population      109.448781

# %%
df_incidence.to_csv('cleaned_incidence_rate_data.csv', index=False)

# %%
#---------------------------------------------------------------------------REPORTED CASES DATA CLEANING--------------------------------------------------------------------------------------------------------------

# %%
df_reported_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84870 entries, 0 to 84869
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GROUP                84870 non-null  object
#  1   CODE                 84869 non-null  object
#  2   NAME                 84869 non-null  object
#  3   YEAR                 84869 non-null  float64
#  4   DISEASE              84869 non-null  object
#  5   DISEASE_DESCRIPTION  84869 non-null  object
#  6   CASES                65470 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 4.5+ MB

# %%
df_reported_cases.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 84865    False
# 84866    False
# 84867    False
# 84868    False
# 84869    False
# Length: 84870, dtype: bool

# %%
df_reported_cases.drop_duplicates(inplace=True)

# %%
df_reported_cases.isnull().sum()
# Out:
# GROUP                      0
# CODE                       1
# NAME                       1
# YEAR                       1
# DISEASE                    1
# DISEASE_DESCRIPTION        1
# CASES                  19400
# dtype: int64

# %%
df_reported_cases.describe()
# Out:
#                YEAR         CASES
# count  84869.000000  6.547000e+04
# mean    2004.108261  4.472409e+03
# std       12.591396  6.114455e+04
# min     1980.000000  0.000000e+00
# 25%     1994.000000  0.000000e+00
# 50%     2005.000000  1.000000e+00
# 75%     2015.000000  6.300000e+01
# max     2023.000000  4.583555e+06

# %%
df_reported_cases.head()
# Out:
#        GROUP CODE   NAME    YEAR          DISEASE  \
# 0  COUNTRIES  ABW  Aruba  2023.0              CRS
# 1  COUNTRIES  ABW  Aruba  2023.0       DIPHTHERIA
# 2  COUNTRIES  ABW  Aruba  2023.0  INVASIVE_MENING
# 3  COUNTRIES  ABW  Aruba  2023.0          MEASLES
# 4  COUNTRIES  ABW  Aruba  2023.0            MUMPS
#
#               DISEASE_DESCRIPTION  CASES
# 0     Congenital rubella syndrome    0.0
# 1                      Diphtheria    0.0
# 2  Invasive meningococcal disease    1.0
# 3                         Measles    NaN
# 4                           Mumps    0.0

# %%
reported_mean=df_reported_cases['CASES'].mean()
df_reported_cases.loc[:,'CASES']=df_reported_cases['CASES'].fillna(reported_mean)

# %%
df_reported_cases.isnull().sum()
# Out:
# GROUP                  0
# CODE                   1
# NAME                   1
# YEAR                   1
# DISEASE                1
# DISEASE_DESCRIPTION    1
# CASES                  0
# dtype: int64

# %%
df_reported_cases.dropna(inplace=True)

# %%
df_reported_cases.isnull().sum()
# Out:
# GROUP                  0
# CODE                   0
# NAME                   0
# YEAR                   0
# DISEASE                0
# DISEASE_DESCRIPTION    0
# CASES                  0
# dtype: int64

# %%
df_reported_cases['YEAR']=df_reported_cases['YEAR'].astype('int')
df_reported_cases['CASES']=df_reported_cases['CASES'].astype('int')

# %%
df_reported_cases.rename(columns=lambda x: x.strip().lower(), inplace=True)
df_reported_cases=df_reported_cases.rename(columns={'group' : 'group_name'})

# %%
df_reported_cases.head()
# Out:
#   group_name code   name  year          disease  \
# 0  COUNTRIES  ABW  Aruba  2023              CRS
# 1  COUNTRIES  ABW  Aruba  2023       DIPHTHERIA
# 2  COUNTRIES  ABW  Aruba  2023  INVASIVE_MENING
# 3  COUNTRIES  ABW  Aruba  2023          MEASLES
# 4  COUNTRIES  ABW  Aruba  2023            MUMPS
#
#               disease_description  cases
# 0     Congenital rubella syndrome      0
# 1                      Diphtheria      0
# 2  Invasive meningococcal disease      1
# 3                         Measles   4472
# 4                           Mumps      0

# %%
df_reported_cases.to_csv('cleaned_reported_cases_data.csv', index=False)

# %%
#------------------------------------------------------------------------VACCINE INTRODUCTION DATA CLEANING---------------------------------------------------------------------------------------------------------

# %%
df_vaccine_introduction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138321 entries, 0 to 138320
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ISO_3_CODE   138321 non-null  object
#  1   COUNTRYNAME  138320 non-null  object
#  2   WHO_REGION   138320 non-null  object
#  3   YEAR         138320 non-null  float64
#  4   DESCRIPTION  138320 non-null  object
#  5   INTRO        138320 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 6.3+ MB

# %%
df_vaccine_introduction.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 138316    False
# 138317    False
# 138318    False
# 138319    False
# 138320    False
# Length: 138321, dtype: bool

# %%
df_vaccine_introduction.drop_duplicates(inplace=True)

# %%
df_vaccine_introduction.isnull().sum()
# Out:
# ISO_3_CODE     0
# COUNTRYNAME    1
# WHO_REGION     1
# YEAR           1
# DESCRIPTION    1
# INTRO          1
# dtype: int64

# %%
df_vaccine_introduction.dropna(inplace=True)

# %%
df_vaccine_introduction.isnull().sum()
# Out:
# ISO_3_CODE     0
# COUNTRYNAME    0
# WHO_REGION     0
# YEAR           0
# DESCRIPTION    0
# INTRO          0
# dtype: int64

# %%
df_vaccine_introduction['YEAR']=df_vaccine_introduction['YEAR'].astype('int')
df_vaccine_introduction=df_vaccine_introduction.rename(columns={'COUNTRYNAME' : 'COUNTRY_NAME'})

# %%
df_vaccine_introduction.rename(columns=lambda x: x.strip().lower(), inplace=True)

# %%
df_vaccine_introduction.head()
# Out:
#   iso_3_code country_name who_region  year  \
# 0        AFG  Afghanistan       EMRO  2023
# 1        AFG  Afghanistan       EMRO  2023
# 2        AFG  Afghanistan       EMRO  2023
# 3        AFG  Afghanistan       EMRO  2023
# 4        AFG  Afghanistan       EMRO  2023
#
#                                    description intro
# 0             aP (acellular pertussis) vaccine    No
# 1                          Hepatitis A vaccine    No
# 2                          Hepatitis B vaccine   Yes
# 3                              HepB birth dose   Yes
# 4  Hib (Haemophilus influenzae type B) vaccine   Yes

# %%
df_vaccine_introduction.to_csv('cleaned_vaccine_introduction_data.csv', index=False)

# %%
#-----------------------------------------------------------------------VACCINE SCHEDULE DATA CLEANING----------------------------------------------------------------------------------------

# %%
df_vaccine_schedule.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8053 entries, 0 to 8052
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ISO_3_CODE             8053 non-null   object
#  1   COUNTRYNAME            8052 non-null   object
#  2   WHO_REGION             8052 non-null   object
#  3   YEAR                   8052 non-null   float64
#  4   VACCINECODE            8052 non-null   object
#  5   VACCINE_DESCRIPTION    8052 non-null   object
#  6   SCHEDULEROUNDS         8052 non-null   float64
#  7   TARGETPOP              3795 non-null   object
#  8   TARGETPOP_DESCRIPTION  8052 non-null   object
#  9   GEOAREA                8022 non-null   object
#  10  AGEADMINISTERED        7007 non-null   object
#  11  SOURCECOMMENT          5139 non-null   object
# dtypes: float64(2), object(10)
# memory usage: 755.1+ KB

# %%
df_vaccine_schedule.tail()
# Out:
#                          ISO_3_CODE COUNTRYNAME WHO_REGION    YEAR  \
# 8048                            ZWE    Zimbabwe       AFRO  2023.0
# 8049                            ZWE    Zimbabwe       AFRO  2023.0
# 8050                            ZWE    Zimbabwe       AFRO  2023.0
# 8051                            ZWE    Zimbabwe       AFRO  2023.0
# 8052  Created: 2025-02-01 16:10 UTC         NaN        NaN     NaN
#
#      VACCINECODE    VACCINE_DESCRIPTION  SCHEDULEROUNDS TARGETPOP  \
# 8048    VITAMINA  Vitamin A supplements             3.0       NaN
# 8049    VITAMINA  Vitamin A supplements             4.0       NaN
# 8050    VITAMINA  Vitamin A supplements             5.0       NaN
# 8051    VITAMINA  Vitamin A supplements             6.0       NaN
# 8052         NaN                    NaN             NaN       NaN
#
#      TARGETPOP_DESCRIPTION   GEOAREA AGEADMINISTERED SOURCECOMMENT
# 8048       General/routine  NATIONAL             M18        M6-M59
# ...

# %%
df_vaccine_schedule.drop_duplicates(inplace=True)

# %%
df_vaccine_schedule.isnull().sum()
# Out:
# ISO_3_CODE                  0
# COUNTRYNAME                 1
# WHO_REGION                  1
# YEAR                        1
# VACCINECODE                 1
# VACCINE_DESCRIPTION         1
# SCHEDULEROUNDS              1
# TARGETPOP                4258
# TARGETPOP_DESCRIPTION       1
# GEOAREA                    31
# AGEADMINISTERED          1046
# SOURCECOMMENT            2914
# dtype: int64

# %%
schedule_mean=df_vaccine_schedule['SCHEDULEROUNDS'].mean()
df_vaccine_schedule.loc[:,'SCHEDULEROUNDS']=df_vaccine_schedule['SCHEDULEROUNDS'].fillna(schedule_mean)

# %%
df_vaccine_schedule.dropna(inplace=True)

# %%
df_vaccine_schedule.isnull().sum()
# Out:
# ISO_3_CODE               0
# COUNTRYNAME              0
# WHO_REGION               0
# YEAR                     0
# VACCINECODE              0
# VACCINE_DESCRIPTION      0
# SCHEDULEROUNDS           0
# TARGETPOP                0
# TARGETPOP_DESCRIPTION    0
# GEOAREA                  0
# AGEADMINISTERED          0
# SOURCECOMMENT            0
# dtype: int64

# %%
df_vaccine_schedule['YEAR']=df_vaccine_schedule['YEAR'].astype('int')
df_vaccine_schedule=df_vaccine_schedule.rename(columns={'COUNTRYNAME' : 'COUNTRY_NAME',
                                                        'VACCINECODE' : 'VACCINE_CODE',
                                                        'SCHEDULEROUNDS' : 'SCHEDULE_ROUNDS',
                                                        'TARGETPOP' : 'TARGET_POPULATION',
                                                        'GEOAREA' : 'GEO AREA',
                                                        'AGEADMINISTERED' : 'AGE_ADMINISTERED',
                                                        'SOURCECOMMENT' : 'SOURCE_COMMENT'
                                                        })

# %%
df_vaccine_schedule['SCHEDULE_ROUNDS']=df_vaccine_schedule['SCHEDULE_ROUNDS'].astype('int')

# %%
df_vaccine_schedule.rename(columns=lambda x: x.strip().lower(), inplace=True)

# %%
df_vaccine_schedule.head()
# Out:
#    iso_3_code country_name who_region  year vaccine_code  \
# 6         ABW        Aruba       AMRO  2023      DTAPIPV
# 7         ABW        Aruba       AMRO  2023      DTAPIPV
# 8         ABW        Aruba       AMRO  2023      DTAPIPV
# 9         ABW        Aruba       AMRO  2023   HEPA_ADULT
# 10        ABW        Aruba       AMRO  2023   HEPA_ADULT
#
#              vaccine_description  schedule_rounds target_population  \
# 6   DTaP-IPV (acellular) vaccine                1        RISKGROUPS
# 7   DTaP-IPV (acellular) vaccine                2        RISKGROUPS
# 8   DTaP-IPV (acellular) vaccine                3        RISKGROUPS
# 9      Adult Hepatitis A vaccine                1        TRAVELLERS
# 10     Adult Hepatitis A vaccine                2        TRAVELLERS
#
#    targetpop_description  geo area age_administered  \
# 6          Risk group(s)  NATIONAL      1st contact
# 7          Risk group(s)  NATIONAL              +M1
# ...

# %%
df_vaccine_schedule.to_csv('cleaned_vaccine_schedule_data.csv', index=False)

# %%
#------------------------------------------------------------------CLEANED SAVED DATA--------------------------------------------------------------------------------

# %%
coverage_data=pd.read_csv("cleaned_coverage_data.csv")
incidence_data=pd.read_csv("cleaned_incidence_rate_data.csv")
reported_cases=pd.read_csv("cleaned_reported_cases_data.csv")
vaccine_introduction=pd.read_csv("cleaned_vaccine_introduction_data.csv")
vaccine_schedule=pd.read_csv('cleaned_vaccine_schedule_data.csv')

# %%
#------------------------------------------------------------------EDA ANALYSIS---------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lineplot(data=coverage_data, x='year',y='coverage')
plt.xlabel('Year')
plt.ylabel('Coverage')
# Out:
# Text(0, 0.5, 'Coverage')

# %%
sns.pairplot(vaccine_schedule,hue='who_region')

# %%
numeric_df = coverage_data.select_dtypes(include=[np.number])
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(coverage_data['target_number'], kde=True, bins=30)
plt.title('Distribution of Doses')
plt.xlabel('Doses')
plt.ylabel('Frequency')
plt.show()

# %%
sns.barplot(data=vaccine_schedule, x='year', y='schedule_rounds', hue='who_region')
plt.show()

# %%
intro = vaccine_introduction['intro'].value_counts()
plt.figure(figsize=(5,5))
plt.pie(intro,labels= intro.index,autopct='%1.1f%%', startangle=90)
plt.title('Vaccine Introduction')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(17,6))
sns.histplot(reported_cases['disease'], kde=True, color="m")
# Out:
# <Axes: xlabel='disease', ylabel='Count'>

# %%
sns.set(style='dark')
sns.lineplot(x="incidence_rate",
             y="year",
             hue="disease",
             data=incidence_data)
# Out:
# <Axes: xlabel='incidence_rate', ylabel='year'>

# %%
sns.barplot(data=incidence_data,x='incidence_rate',y='disease')
# Out:
# <Axes: xlabel='incidence_rate', ylabel='disease'>
